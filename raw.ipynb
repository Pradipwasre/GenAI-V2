# %%
a = ["milk" , "bread"]

# %%
a.append("Rice")

# %%
a
# Out:
# ['milk', 'bread', 'Rice']

# %%
a.insert(0 , "Water")

# %%
print(a)
# Out:
# ['Water', 'milk', 'bread', 'Rice']

# %%
shop_1 = ["Charger" , "Mobile" , "Pillow" , "Pen"]

# %%
shop_2 = ["Chips" , "Coke", "RedBull" , "Iphone"]

# %%
shop_1.extend(shop_2)
shop_1
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

# %%
shop_1[-1]
# Out:
# 'Iphone'

# %%
shop_1 # extend
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

# %%
shop_1 = ["Charger" , "Mobile" , "Pillow" , "Pen"]
shop_2 = ["Chips" , "Coke", "RedBull" , "Iphone"]
shop_1.extend(shop_2)
shop_1 # Extend
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

# %%
shop_1[7]
# Out:
# 'Iphone'

# %%
shop_1 = ["Charger" , "Mobile" , "Pillow" , "Pen"]
shop_2 = ["Chips" , "Coke", "RedBull" , "Iphone"]
shop_1.append(shop_2)
shop_1 # Append
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', ['Chips', 'Coke', 'RedBull', 'Iphone']]

# %%
shop_1[4][0]
# Out:
# 'Chips'

# %%
shop_1 = ["Charger" , "Mobile" , "Pillow" , "Pen"]
shop_2 = ["Chips" , "Coke", "RedBull" , "Iphone"]
shop_1.extend(shop_2)
shop_1 # Extend
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

# %%
shop_1.remove('Pillow')
shop_1
# Out:
# ['Charger', 'Mobile', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

# %%
shop_1.remove('Pen')

# %%
shop_1.remove("Books")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 shop_1.remove("Books")
#
# ValueError: list.remove(x): x not in list

# %%
shop_1 = ["Charger" , "Mobile" , "Pillow" , "Pen"]
shop_2 = ["Chips" , "Coke", "RedBull" , "Iphone"]
shop_1.extend(shop_2)
shop_1 # Extend
# Out:
# ['Charger', 'Mobile', 'Pillow', 'Pen', 'Chips', 'Coke', 'RedBull', 'Iphone']

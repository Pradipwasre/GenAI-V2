# %% [markdown]
# # Lecture: All About Prompts
#
# ---
#
# ## 1. Warm-Up & Context
# - Why prompts matter in GenAI
# - Small changes → big differences in outputs
# - Prompt Engineering as an emerging skill/job role
#
# ---
#
# ## 2. Vanilla Prompt Styles (Without LangChain)
#
# ## Core Techniques
# 1. **Instruction Prompts** → Direct commands (e.g., "Summarize this article in 3 bullet points")
# 2. **Zero‑Shot Prompts** → No examples, rely on model’s pretraining
# 3. **Few‑Shot Prompts** → Provide a few examples before the query
# 4. **Chain‑of‑Thought Prompts** → Encourage reasoning step by step
# 5. **Role‑Based Prompts** → Assign persona (e.g., "You are a Python tutor…")
# 6. **Deliberate (Self‑Consistency) Prompts** → Multiple reasoning paths → consistent answer
# 7. **Prompt Chaining** → Sequential prompts → step‑by‑step workflow
# 8. **ReAct Prompts (Reason + Act)** → Combine reasoning + tool actions
#
# ## Additional Techniques
#
# 9. **Contextual Prompts** → Provide background info before asking
# 10. **Conversational Prompts** → Simulate dialogue with alternating turns
# 11. **Multimodal Prompts** → Combine text + image/audio/video (if supported)
# 12. **RAG (Retrieval‑Augmented Generation) Prompts** → Connect LLMs with external knowledge bases
# ---
#
# ## 3. Why LangChain?
# - **Challenge with vanilla prompts:**
#   - Hard to maintain consistency across applications
#   - No built-in validation → errors if placeholders are missing
#   - Difficult to reuse prompts across projects
#   - Managing multi-turn conversations is messy
# - **LangChain solves these problems by:**
#   - Providing structured classes (`PromptTemplate`, `ChatPromptTemplate`)
#   - Adding validation and error-checking
#   - Enabling reusability (save/load templates)
#   - Integrating prompts seamlessly with chains and workflows
#   - Supporting advanced features like role-based messages and dynamic chat history
# - **Most reasonable reason to use LangChain:**
#   It transforms *ad-hoc experimentation* into *production-ready workflows* with clarity, consistency, and context management.
#
# ---
#
# ## 4. LangChain Prompt Types
# - **Static Prompts** → Hardcoded text (simple, but error-prone)
# - **Dynamic Prompts** → Templates with placeholders (flexible, consistent)
# - **PromptTemplate Class** → Validation, reusability, integration
# - **ChatPromptTemplate** → Multi-turn conversations with role-based messages
# - **Message Types**:
#   - SystemMessage → sets assistant’s role/context
#   - HumanMessage → user input
#   - AIMessage → model response
# - **MessagePlaceholder** → Insert chat history dynamically at runtime
#
# ---

# %%
pip install groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\admin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# %%
# Load environment variables from .env file
load_dotenv()

# Get the GROQ API key
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
# Print to verify (optional, avoid in production)
print("Loaded GROQ API Key:", groq_api_key[:5] + "..." if groq_api_key else "Not Found")
# Out:
# Loaded GROQ API Key: gsk_R...

# %% [markdown]
# # Instruction Prompts
#
# ---
#
# ## Definition
# Direct commands or tasks given to the model.
#
# ---
#
# ## How it Works
# - The LLM interprets the instruction literally.
# - Produces output directly aligned with the command.
# - No examples or context are required, just the instruction itself.
#
# ---
#
# ## Example
# - "Summarize this article in 3 bullet points."
# - "Translate the following sentence into French."
# - "Write a short poem about cricket."
#
# ---
#
# ## Use Cases
# - Q&A systems
# - Summarization
# - Translation
# - Content generation
# - Quick factual or creative tasks
#
# ---
#
# ## Hands-On Exercise (with GROQ)
# We’ll use the GROQ API to send a simple instruction prompt.

# %%
# Initialize client
client = Groq(api_key=groq_api_key)

# %%
# Send an instruction prompt
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # choose a supported model
    messages=[
        {"role": "user", "content": "Explain why water is important for life."}
    ]
)

# %%
# Print the output
print(response.choices[0].message.content)
# Out:
# Water is crucial for life on Earth and plays a vital role in the functioning of all living organisms. Here are some reasons why water is essential for life:
#
# 1. **Cellular Structure and Function**: Water makes up approximately 55-60% of the human body, and it's a key component of cells, which are the basic building blocks of life. Water is necessary for cellular structure, function, and regulation.
#
# 2. **Temperature Regulation**: Water helps regulate the body's temperature by transporting heat away from the brain and other vital organs. It also helps to cool the body through sweating.
#
# 3. **Digestion and Absorption**: Water is necessary for the digestion and absorption of nutrients in the body. It helps to break down food, absorb vitamins and minerals, and transport nutrients to cells.
#
# 4. **Waste Removal**: Water helps to remove waste products from the body by flushing out toxins and waste through urine and sweat.
#
# ...

# %% [markdown]
# # Instruction Prompts: Hands-On
#
# ---
#
# ## What We Write
# - We give the model a **direct command** or task.
# - Example: `"Explain why water is important for life."`
# - This is plain text, no examples or context, just the instruction.
#
# ---
#
# ## How It Works with the Model
# - The LLM reads the instruction as the **user’s intent**.
# - It generates output aligned with the command:
#   - If asked to summarize → it condenses information.
#   - If asked to translate → it converts text into another language.
#   - If asked to write → it produces creative or factual text.
#
# ---

# %% [markdown]
# #  Understanding the Response
#
# ---
#
# The API returns a **response object** with multiple fields.
# The actual text generated by the model is inside:
#
# ```python
# response.choices[0].message.content

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-ec261c73-14ab-4ec5-a22f-214869284f1c', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Water is crucial for life on Earth and plays a vital role in the functioning of all living organisms. Here are some reasons why water is essential for life:\n\n1. **Cellular Structure and Function**: Water makes up approximately 55-60% of the human body, and it's a key component of cells, which are the basic building blocks of life. Water is necessary for cellular structure, function, and regulation.\n\n2. **Temperature Regulation**: Water helps regulate the body's temperature by transporting heat away from the brain and other vital organs. It also helps to cool the body through sweating.\n\n3. **Digestion and Absorption**: Water is necessary for the digestion and absorption of nutrients in the body. It helps to break down food, absorb vitamins and minerals, and transport nutrients to cells.\n\n4. **Waste Removal**: Wa
# ...

# %% [markdown]
# ## Breakdown
#
# -   `response.choices` → a list of possible outputs (usually 1 by default).
# -   `[0]` → selects the first choice in the list.
# -   `.message` → the message object returned by the model.
# -   `.content` → the actual text string generated by the LLM.

# %% [markdown]
# # Understanding the Response Object
#
# ---
#
# When we call the API, it returns a **response object** with multiple fields.
# Here’s what a typical response looks like (simplified):
#
# ```json
# {
#   "id": "chatcmpl-123",
#   "object": "chat.completion",
#   "created": 1677652288,
#   "model": "llama-3.1-8b-instant",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "- AI improves efficiency by automating tasks.\n- AI enables better decision-making with data insights.\n- AI drives innovation across industries."
#       },
#       "finish_reason": "stop"
#     }
#   ]
# }

# %% [markdown]
# # 2. Zero-Shot Prompts
#
# ---
#
# ## Definition
# Zero-Shot Prompting is a technique where a **Large Language Model (LLM)** is asked to perform a task **without being given any examples or demonstrations** in the prompt.
# - The model relies entirely on its **pretrained knowledge** and **general understanding** of language and concepts.
# - This approach is part of **Zero-Shot Learning (ZSL)**, where AI systems solve tasks they haven’t been explicitly trained on, using prior knowledge.
#
# ---
#
# ##  How It Works
# 1. **Direct Instruction** → The user provides a clear command or query.
# 2. **No Examples Provided** → Unlike few-shot prompting, the model is not shown sample inputs/outputs.
# 3. **Model Generalization** → The LLM uses its **internal training data** and **generalization ability** to infer the correct response.
# 4. **Output Generation** → The model produces an answer based purely on prior knowledge, without external guidance.
#
# ---
#
# ##  Why It Matters
# - **Efficiency** → No need to craft multiple examples; saves time.
# - **Flexibility** → Works across diverse tasks (classification, summarization, translation, etc.).
# - **Scalability** → Useful when examples are unavailable or impractical to provide.
# - **Demonstrates Generalization** → Shows how LLMs can apply knowledge to new, unseen tasks.
#
# ---
#
# ##  Use Cases
# - **Sentiment Analysis** → *“Classify the sentiment of: ‘I love this product.’”*
# - **Text Summarization** → *“Summarize this article in 3 bullet points.”*
# - **Translation** → *“Translate this sentence into French.”*
# - **Q&A** → *“What is the capital of Japan?”*
# - **Content Generation** → *“Write a short poem about the ocean.”*
#
# ---
#
# ##  Key Insights
# - Zero-Shot Prompts highlight the **power of pretraining** in LLMs.
# - They are best for **simple, well-known tasks** where the model’s training already covers the concept.
# - For **complex or domain-specific tasks**, few-shot or chain-of-thought prompting may yield better accuracy.
# - In practice, Zero-Shot is often the **first step** before refining prompts with examples or structured frameworks.

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Zero-Shot Prompt Example: Summarization
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": "Summarize the importance of AI in 3 bullet points."}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Here are three bullet points summarizing the importance of AI:
#
# • **Enhanced Efficiency and Productivity**: Artificial intelligence (AI) automates routine tasks, freeing up human resources for more creative, strategic, and high-value work. This leads to increased efficiency, productivity, and better decision-making. AI also helps organizations streamline processes, reduce errors, and save time and money.
#
# • **Improved Accuracy and Data Analysis**: AI's machine learning capabilities enable it to analyze vast amounts of data, identify patterns, and make predictions. This leads to better decision-making and more accurate outcomes in areas such as healthcare, finance, and customer service. AI also helps organizations detect anomalies and potential security threats.
#
# ...

# %% [markdown]
# ###  Difference Between Instruction Prompts and Zero-Shot Prompts
#
# ---
#
# #### Instruction Prompts
# - **Definition:** Direct commands or tasks given to the model.
# - **How it works:** The LLM interprets the instruction and produces output accordingly.
# - **Strengths:**
#   - Simple and clear.
#   - Best for straightforward tasks.
# - **Example:**
#   "Summarize this article in 3 bullet points."
#
# ---
#
# #### Zero-Shot Prompts
# - **Definition:** Asking the model to perform a task without providing examples.
# - **How it works:** Relies entirely on the model’s pretraining and general knowledge.
# - **Strengths:**
#   - Efficient when examples are unavailable.
#   - Demonstrates the model’s generalization ability.
# - **Example:**
#   "Classify the sentiment of this sentence: 'I love this product.'"
#
# ---
#
# ## Quick Comparison
#
# | Aspect              | Instruction Prompts                          | Zero-Shot Prompts                          |
# |---------------------|----------------------------------------------|--------------------------------------------|
# | **Input Style**     | Direct command                               | Direct command without examples             |
# | **Dependency**      | Relies on clarity of instruction             | Relies on pretrained knowledge              |
# | **Best Use Case**   | Q&A, summarization, translation, generation  | Classification, quick tasks, general tasks  |
# | **Complexity**      | Low                                          | Moderate (depends on model’s training)      |
# | **Examples Needed** | No                                           |   No                                       |
#
# ---
#
# ##  Insight
# - **Instruction Prompts** are the foundation: clear commands that guide the model.
# - **Zero-Shot Prompts** extend this by testing the model’s ability to generalize without examples.
# - Together, they show how LLMs can handle tasks with varying levels of guidance.

# %% [markdown]
# #  Few-Shot Prompts
#
# ---
#
# ## Definition
# Few-Shot Prompting is a technique where the **Large Language Model (LLM)** is given a **few examples of input-output pairs** before the actual query.
# - The goal is to help the model **learn the pattern** or **format** from the examples.
# - Unlike Zero-Shot (no examples) and Instruction (direct command), Few-Shot provides **guidance through demonstrations**.
#
# ---
#
# ## How It Works
# 1. **Provide Examples** → The prompt includes 2–5 sample tasks with their expected answers.
# 2. **Model Learns the Pattern** → The LLM observes the structure, style, or logic in the examples.
# 3. **Apply to New Input** → When given a new query, the model follows the same pattern to generate consistent results.
#
# ---
#
# ##  Why It Matters
# - **Consistency** → Ensures outputs follow a specific style or format.
# - **Control** → Reduces randomness by guiding the model with examples.
# - **Adaptability** → Useful when tasks are domain-specific or require structured responses.
# - **Improved Accuracy** → Helps the model avoid misinterpretation by showing what is expected.
#
# ---
#
# ##  Use Cases
# - **Text Classification** → Providing examples of positive/negative/neutral sentences before asking for a new classification.
# - **Formatting Tasks** → Showing examples of converting text into JSON, tables, or bullet points.
# - **Style Transfer** → Demonstrating how to rewrite sentences in a formal or casual tone.
# - **Domain-Specific Tasks** → Teaching the model specialized terminology or structured outputs.
#
# ---
#
# ## 📝 Example (Conceptual)
# **Prompt:**

# %% [markdown]
# #### Few-Shot Prompt Example: Sentiment Classification
#
# ---
#
# ### Example 1
# **Input:**
# "I love this phone."
# **Output:**
# Positive
#
# ---
#
# ### Example 2
# **Input:**
# "This movie was terrible."
# **Output:**
# Negative
#
# ---
#
# ### Task
# Now classify the sentiment of this sentence:
# **Input:**
# "The food was okay, nothing special."
#
# **Expected Output:**
# Neutral
#
# ---
#
# ##  Insight
# - The model is shown **two examples** (Positive and Negative) before being asked to classify a new sentence.
# - This helps the LLM **learn the pattern** and apply it consistently.
# - Few-Shot prompting is especially useful for **classification tasks, formatting, and domain-specific outputs**.

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Few-Shot Prompt Example: Sentiment Classification
few_shot_prompt = """
Example 1:
Input: "I love this phone."
Output: Positive

Example 2:
Input: "This movie was terrible."
Output: Negative

Now classify the sentiment of this sentence:
Input: "The food was okay, nothing special."
"""

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": few_shot_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The sentiment of the sentence "The food was okay, nothing special" is neutral.
#
# Here's why:
# - The word "okay" suggests that the speaker is not overly enthusiastic about the food, but is also not extremely dissatisfied.
# - The phrase "nothing special" implies that the food did not exceed expectations, but it doesn't necessarily convey a negative opinion.
# - The tone of the sentence is more matter-of-fact than emotional, which also points towards a neutral sentiment.
#
# So, the classification of the sentiment is: Neutral.

# %% [markdown]
# #  Chain-of-Thought (CoT) Prompts in Generative AI
#
# ---
#
# ####  Definition
# Chain-of-Thought (CoT) Prompting is a technique where the **Large Language Model (LLM)** is encouraged to **reason step-by-step** before producing the final answer.
# - Instead of giving a direct response, the model is guided to **show its intermediate reasoning process**.
# - This is especially useful for tasks involving **logic, math, multi-step reasoning, or problem-solving**.
#
# ---
#
# #### How It Works
# 1. **Prompt Design** → The user explicitly asks the model to "think step by step" or "show reasoning."
# 2. **Reasoning Generation** → The LLM produces intermediate steps, calculations, or logical deductions.
# 3. **Final Answer** → After reasoning, the model provides the final solution.
#
# ---
#
# ####  Why It Matters
# - **Improves Accuracy** → By breaking down reasoning, the model reduces errors in complex tasks.
# - **Transparency** → Users can see how the model arrived at its answer.
# - **Problem-Solving** → Essential for math, logic puzzles, and multi-step decision-making.
# - **Educational Value** → Helps learners understand the reasoning process, not just the result.
#
# ---
#
# ####  Use Cases
# - **Mathematics** → Solving equations, word problems, or step-by-step calculations.
# - **Logic Puzzles** → Explaining reasoning before giving the solution.
# - **Decision-Making** → Outlining pros/cons before making a recommendation.
# - **Programming Help** → Explaining debugging steps before suggesting fixes.
#
# ---
#
# ####  Example (Conceptual)
# **Prompt:**
# "Multiply 23 by 47. Think step by step before giving the final answer."
#
# **Model Response (Chain-of-Thought):**
# 1. Break 47 into (40 + 7).
# 2. Compute 23 × 40 = 920.
# 3. Compute 23 × 7 = 161.
# 4. Add results: 920 + 161 = 1081.
#
# **Final Answer:**
# 1081
#
# ---
#
# #### Key Insights
# - Chain-of-Thought prompts **force the model to reason explicitly**.
# - They are most effective for **complex, multi-step tasks**.
# - Unlike Zero-Shot or Few-Shot, CoT is not about examples, it’s about **reasoning transparency**.
# - In practice, adding phrases like *“think step by step”* or *“show your reasoning”* can significantly improve results.
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Chain-of-Thought Prompt Example: Math Reasoning
cot_prompt = """
Multiply 24 by 100. Think step by step before giving the final answer.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": cot_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# To multiply 24 by 100, I will break it down step by step.
#
# 1. Multiply 24 by 100, which can be thought of as multiplying 24 by (10 * 10).
# 2. Multiply 24 by 10: 24 * 10 = 240
# 3. Multiply the result (240) by 10: 240 * 10 = 2400
#
# So, the result of multiplying 24 by 100 is 2400.

# %% [markdown]
# ---
#
# ### Chain-of-Thought (CoT) Prompt
# - **Definition:** Encouraging the model to reason step-by-step before giving the final answer.
# - **How it works:** The model shows intermediate reasoning, calculations, or logic before the solution.
# - **Best Use Cases:**
# - Math problems and logical reasoning.
# - Multi-step decision-making.
# - Complex problem-solving where transparency is important.
# - **Example:**
# "Multiply 23 by 47. Think step by step before giving the final answer."
#
# ---
#
# #### Quick Comparison Table
#
# | Technique            | Definition                                | Best Use Cases                                   | Example |
# |----------------------|--------------------------------------------|-------------------------------------------------|---------|
# | **Instruction**      | Direct command                            | Summarization, translation, Q&A                 | "Summarize AI in 3 bullet points." |
# | **Zero-Shot**        | No examples, relies on pretrained knowledge | Classification, general queries                 | "Classify sentiment: 'I love this product.'" |
# | **Few-Shot**         | A few examples guide the output           | Domain-specific, formatting, style transfer     | Sentiment classification with 2 examples |
# | **Chain-of-Thought** | Explicit reasoning steps before answer    | Math, logic puzzles, multi-step reasoning       | "Multiply 23 by 47. Think step by step." |
#
# ---
#
# ####  Insight
# - **Instruction Prompt** → Best for **simple, direct tasks**.
# - **Zero‑Shot Prompt** → Best when **no examples are available** and the model can rely on its training.
# - **Few‑Shot Prompt** → Best when you need **structured, domain-specific, or consistent outputs**.
# - **Chain‑of‑Thought Prompt** → Best for **complex reasoning, math, and logic problems**.
#
# Together, these techniques form the **core toolkit of prompt engineering**, allowing you to adapt the model’s behavior depending on the complexity and context of the task.

# %% [markdown]
# # 5. Role Prompting
# ---
#
# ### Definition
# Role Prompting is a technique where the **Large Language Model (LLM)** is asked to **take on a specific role, persona, or identity** before performing a task.
# - Instead of just giving instructions, you frame the prompt by assigning the model a role (e.g., teacher, doctor, programmer, historian).
# - This influences the **tone, style, and perspective** of the response.
#
# ---
#
# ####  How It Works
# 1. **Assign a Role** → The prompt begins with "You are a..." or "Act as a...".
# 2. **Contextual Framing** → The model adapts its language, tone, and reasoning to fit the role.
# 3. **Task Execution** → The model performs the requested task while maintaining the assigned persona.
#
# ---
#
# #### Why It Matters
# - **Control Style & Tone** → Ensures responses match the desired perspective.
# - **Domain Adaptation** → Useful for specialized fields (medicine, law, education, etc.).
# - **Engagement** → Makes outputs more relatable and context‑appropriate.
# - **Consistency** → Helps maintain a coherent narrative or teaching style.
#
# ---
#
# #### Use Cases
# - **Education** → "You are a math teacher. Explain fractions to a 10‑year‑old."
# - **Programming Help** → "Act as a Python tutor. Explain how loops work with examples."
# - **Creative Writing** → "You are a poet. Write a haiku about the ocean."
# - **Professional Guidance** → "Act as a career coach. Suggest strategies for improving communication skills."
#
# ---
#
# #### Example (Conceptual)
# **Prompt:**
# "You are a historian. Explain the importance of the Industrial Revolution in simple terms."
#
# **Model Response (Role‑Based):**
# "As a historian, I would say the Industrial Revolution was a turning point in human history. It shifted societies from farming to factories, introduced machines, and transformed economies worldwide."
#
# ---
#
# #### Key Insights
# - Role Prompting is about **framing the model’s identity** before the task.
# - It is especially powerful when you want **domain‑specific expertise or stylistic control**.
# - Compared to other techniques:
#   - **Instruction Prompt** → Direct command.
#   - **Zero‑Shot Prompt** → No examples, relies on pretrained knowledge.
#   - **Few‑Shot Prompt** → A few examples guide the output.
#   - **Chain‑of‑Thought Prompt** → Explicit reasoning steps before the answer.
#   - **Role Prompt** → Assigns a persona to shape tone, style, and perspective.
#
# ---
#
# ####  Where to Use Each Type
#
# | Technique            | Best Use Case                                                                 |
# |----------------------|-------------------------------------------------------------------------------|
# | **Instruction**      | Simple, direct tasks (summarization, translation, Q&A).                       |
# | **Zero‑Shot**        | Quick tasks without examples (classification, general queries).               |
# | **Few‑Shot**         | Domain‑specific or structured outputs (classification with examples, formatting). |
# | **Chain‑of‑Thought** | Complex reasoning, math, logic puzzles, multi‑step problem solving.           |
# | **Role Prompting**   | Domain adaptation, stylistic control, professional/creative personas.         |
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Role Prompt Example: Act as a Python Tutor
role_prompt = """
You are a Python tutor. 
Explain how loops work in Python with a simple example suitable for beginners.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": role_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# **Loops in Python**
# ...
#
# Loops are a fundamental concept in programming that allow you to execute a block of code repeatedly. In Python, there are two types of loops: **for loop** and **while loop**.
#
# **For Loop**
# ------------
#
# A for loop is used to iterate over a sequence (such as a list, tuple, or string) and execute a block of code for each item in the sequence.
#
# **Example:**
# ```python
# # Create a list of fruits
# fruits = ["apple", "banana", "cherry"]
#
# # Use a for loop to print each fruit
# for fruit in fruits:
#     print(fruit)
# ```
# Output:
# ```
# apple
# banana
# cherry
# ```
# In this example, the for loop iterates over the `fruits` list, assigning each item to the variable `fruit`. The block of code inside the loop (`print(fruit)`) is executed for each item in the list.
#
# **While Loop**
# -------------
#
# A while loop is used to execute a block of code as long as a certain condition is true.
#
# **Example:**
# ```python
# ...

# %% [markdown]
# ### Role Prompting — What Happens Here
#
# ---
# - The model is explicitly told to **act as a Python tutor**.
# - This shapes the **tone and style** of the response — it will explain loops in a teaching style, likely with beginner‑friendly examples.
# - Role Prompting is powerful when you want **domain‑specific expertise or stylistic control** (e.g., teacher, lawyer, poet, coach).
#
# ---
#
# ###  Where to Use Role Prompting
# - **Education** → Teaching concepts step by step.
# - **Professional Guidance** → Acting as a coach, consultant, or advisor.
# - **Creative Writing** → Taking on personas like poet, storyteller, or historian.
# - **Customer Support Simulation** → Acting as a support agent or product expert.
#
# ---
#
# ###  Insight
# Role Prompting is about **framing the model’s identity** before the task.
# It ensures the response is **context‑appropriate, stylistically consistent, and domain‑specific**.

# %% [markdown]
# ## 6. Deliberate (Self-Consistency) Prompting in Generative AI
#
# ---
#
# #### Definition
# Deliberate Prompting is a technique where the **Large Language Model (LLM)** is asked to **generate multiple reasoning paths or answers** and then select the most consistent or deliberate final output.
# - Instead of relying on a single response, the model explores **different possible solutions**.
# - The final answer is chosen based on **consistency across reasoning paths**.
#
# ---
#
# #### How It Works
# 1. **Prompt Design** → Ask the model to "think of multiple possible answers" or "consider different approaches."
# 2. **Generate Variations** → The LLM produces several reasoning paths or candidate outputs.
# 3. **Select Consistent Answer** → The most common or consistent result is chosen as the final answer.
#
# ---
#
# #### Why It Matters
# - **Improves Reliability** → Reduces the chance of random or incorrect outputs.
# - **Handles Ambiguity** → Useful when tasks have multiple possible interpretations.
# - **Boosts Accuracy** → By comparing multiple reasoning paths, the model avoids single-path errors.
# - **Transparency** → Shows how different reasoning approaches converge on the same solution.
#
# ---
#
# #### Use Cases
# - **Math & Logic Problems** → Generating multiple solution paths to verify correctness.
# - **Decision-Making** → Exploring different options before recommending one.
# - **Creative Writing** → Producing several drafts and selecting the most coherent.
# - **Classification** → Running multiple reasoning paths to ensure consistent labeling.
#
# ---
#
# #### Example (Conceptual)
# **Prompt:**
# "Multiply 23 by 47. Think of at least two different ways to solve this, then give the final answer."
#
# **Model Response (Deliberate):**
# - Path 1: Break 47 into (40 + 7). Compute 23 × 40 = 920, 23 × 7 = 161, total = 1081.
# - Path 2: Use long multiplication. 23 × 47 = 1081.
# - Path 3: Approximate 23 × 50 = 1150, subtract 23 × 3 = 69 → 1081.
#
# **Final Answer:**
# 1081
#
# ---
#
# ### Key Insights
# - Deliberate Prompting asks the model to **explore multiple reasoning paths**.
# - The final answer is chosen based on **consistency across those paths**.
# - Compared to other techniques:
#   - **Instruction Prompt** → Direct command.
#   - **Zero‑Shot Prompt** → No examples, relies on pretrained knowledge.
#   - **Few‑Shot Prompt** → A few examples guide the output.
#   - **Chain‑of‑Thought Prompt** → Explicit reasoning steps before the answer.
#   - **Role Prompting** → Assigns a persona to shape tone and style.
#   - **Deliberate Prompting** → Multiple reasoning paths → consistent final answer.
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Deliberate Prompt Example: Multiple Reasoning Paths
deliberate_prompt = """
Multiply 23 by 47. 
Think of at least two different ways to solve this, 
then provide the final consistent answer.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": deliberate_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# **Method 1: Multiplication by Multiplication**
#
# 23 × 40 = 920
# 23 × 7 = 161
# Adding these two results together, we get:
# 920 + 161 = 1081
#
# **Method 2: The Commutative Property and Multiplication by Multiplication**
#
# 47 × 20 = 940
# 47 × 3 = 141
# Adding these two results together, we get:
# 940 + 141 = 1081
#
# **Verification: Multiplication with a calculator**
#
# 23 × 47 = 1081
#
# **Final Answer:**
# The consistent answer to 23 × 47 is 1081.

# %% [markdown]
# ## 7. Prompt Chaining in Generative AI
#
# ---
#
# ###  Definition
# Prompt Chaining is a technique where **multiple prompts are linked together in sequence**, with the output of one prompt serving as the input for the next.
# - Instead of asking the model to solve a complex task in one go, you **break it down into smaller steps**.
# - Each step is handled by a separate prompt, creating a logical chain that leads to the final result.
#
# ---
#
# ### How It Works
# 1. **Break Down the Task** → Divide a complex problem into smaller, manageable subtasks.
# 2. **Design Sequential Prompts** → Each prompt solves one subtask.
# 3. **Chain Outputs** → The output of one prompt becomes the input for the next.
# 4. **Final Result** → The last prompt produces the complete solution.
#
# ---
#
# ### Why It Matters
# - **Improves Accuracy** → Reduces errors by tackling tasks step by step.
# - **Scalability** → Useful for multi-stage workflows (e.g., research, summarization, analysis).
# - **Transparency** → Easier to debug and understand where mistakes occur.
# - **Flexibility** → Each step can be customized or replaced independently.
#
# ---
#
# ### Use Cases
# - **Research Workflows** → First extract key points, then summarize, then generate insights.
# - **Data Processing** → Clean data → classify → format into JSON.
# - **Creative Writing** → Generate outline → expand into draft → polish into final text.
# - **Education** → Step-by-step problem solving (e.g., math or programming exercises).
#
# ---
#
# ## Example (Conceptual)
# **Step 1 Prompt:**
# "Summarize the importance of AI in 3 bullet points."
#
# **Step 1 Output:**
# - AI automates tasks.
# - AI improves decision-making.
# - AI drives innovation.
#
# **Step 2 Prompt (using Step 1 output):**
# "Expand each bullet point into a short paragraph with examples."
#
# **Step 2 Output:**
# - AI automates tasks such as customer support chatbots and manufacturing processes...
# - AI improves decision-making in healthcare diagnostics and financial forecasting...
# - AI drives innovation in self-driving cars, personalized education, and drug discovery...
#
# ---
#
# ## Key Insights
# - Prompt Chaining is about **breaking complex tasks into smaller linked prompts**.
# - Compared to other techniques:
#   - **Instruction Prompt** → Direct command.
#   - **Zero‑Shot Prompt** → No examples, relies on pretrained knowledge.
#   - **Few‑Shot Prompt** → A few examples guide the output.
#   - **Chain‑of‑Thought Prompt** → Explicit reasoning steps before the answer.
#   - **Role Prompting** → Assigns a persona to shape tone and style.
#   - **Deliberate Prompting** → Multiple reasoning paths → consistent final answer.
#   - **Prompt Chaining** → Sequential prompts → step-by-step workflow.
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Step 1: Summarization
step1_prompt = "Summarize the importance of AI in 3 bullet points."

step1_response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": step1_prompt}
    ]
)

# %%
step1_output = step1_response.choices[0].message.content
print("Step 1 Output:\n", step1_output)
# Out:
# Step 1 Output:
#  Here's a summary of the importance of AI in three bullet points:
#
# • **Enhanced Efficiency and Productivity**: Artificial intelligence (AI) can automate routine tasks, freeing up human resources for more strategic and creative work. AI-powered tools can process large amounts of data quickly and accurately, enabling businesses to make data-driven decisions and improve overall efficiency.
#
# • **Improved Accuracy and Decision-Making**: AI algorithms can analyze complex patterns and make predictions or suggestions based on that analysis. This leads to more accurate decision-making, reduced risk, and better outcomes in various fields such as healthcare, finance, and transportation.
#
# ...

# %%
# Step 2: Expansion using Step 1 output
step2_prompt = f"Expand each of the following points into a short paragraph with examples:\n{step1_output}"

step2_response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": step2_prompt}
    ]
)

# %%
step2_output = step2_response.choices[0].message.content
print("\nStep 2 Output:\n", step2_output)
# Out:
# Step 2 Output:
#  **Enhanced Efficiency and Productivity**
#
# The integration of artificial intelligence (AI) into various industries has greatly improved efficiency and productivity. For instance, AI-powered tools can automate routine tasks such as data entry, scheduling, and email management, freeing up human resources to focus on more strategic and creative work. A notable example is the use of AI in customer service, where chatbots can handle basic queries and provide prompt responses, reducing the workload of customer support teams. This enables businesses to allocate more time and resources to developing new products and services, and ultimately, improve their competitive edge. Additionally, AI can also optimize processes such as supply chain management and resource allocation, leading to significant cost savings and improved productivity.
#
# **Improved Accuracy and Decision-Making**
#
# ...

# %% [markdown]
# ### Prompt Chaining — What Happens Here
#
# ---
# - **Step 1 Prompt** → The model summarizes AI in 3 bullet points.
# - **Step 1 Output** → Concise summary (e.g., automation, decision-making, innovation).
# - **Step 2 Prompt** → Uses Step 1 output as input, asking the model to expand each point.
# - **Step 2 Output** → Detailed explanation with examples.
#
# ---
#
# #### Why Prompt Chaining is Useful
# - Breaks down **complex tasks into smaller steps**.
# - Ensures **clarity and accuracy** at each stage.
# - Makes workflows **modular and reusable** (students can swap Step 2 for formatting, JSON conversion, etc.).
#
# ---
#
# #### Insight
# Prompt Chaining is especially powerful for **multi-stage workflows** like research, education, and creative writing.
# It allows you to **control the process step by step**, ensuring that each stage produces reliable and structured outputs.

# %% [markdown]
# ## 8. ReAct Prompting (Reason + Act)
#
# ---
#
# ### Definition
# ReAct Prompting is a technique where the **Large Language Model (LLM)** is guided to **combine reasoning with actions**.
# - The model first **reasons step by step** about the problem.
# - Then it **takes an action** (e.g., calling a tool, retrieving data, or producing an answer).
# - This loop continues until the task is solved.
#
# ---
#
# ### How It Works
# 1. **Reasoning Phase** → The model explains its thought process.
# 2. **Action Phase** → The model executes an action (e.g., search, calculation, API call).
# 3. **Observation Phase** → The model receives results from the action.
# 4. **Repeat if Needed** → The model reasons again and takes further actions until the final answer is ready.
#
# ---
#
# ### Why It Matters
# - **Bridges Thinking and Doing** → The model doesn’t just “think,” it also “acts.”
# - **Dynamic Problem Solving** → Useful for tasks requiring external data or iterative steps.
# - **Transparency** → Shows reasoning and actions clearly.
# - **Agentic AI** → Forms the foundation of autonomous agents that interact with tools.
#
# ---
#
# ### Use Cases
# - **Information Retrieval** → Reason about what’s needed, then call a search API.
# - **Math & Logic** → Reason step by step, then calculate using a tool.
# - **Task Automation** → Break down workflow, act on each step, and combine results.
# - **Interactive Agents** → Chatbots that reason and fetch live data.
#
# ---
#
# ### Example (Conceptual)
# **Prompt:**
# "Find the current population of Japan and explain if it has grown compared to 2020."
#
# **Model Response (ReAct style):**
# - **Reasoning:** To answer, I need Japan’s current population and compare it with 2020 data.
# - **Action:** Call a search tool for "current population of Japan."
# - **Observation:** Population ~124 million (2026).
# - **Reasoning:** In 2020, Japan’s population was ~126 million.
# - **Final Answer:** Japan’s population has declined slightly since 2020.
#
# ---
#
# ### Key Insights
# - ReAct Prompting combines **Chain-of-Thought reasoning** with **tool usage/actions**.
# - Compared to other techniques:
#   - **Instruction Prompt** → Direct command.
#   - **Zero‑Shot Prompt** → No examples, relies on pretrained knowledge.
#   - **Few‑Shot Prompt** → A few examples guide the output.
#   - **Chain‑of‑Thought Prompt** → Explicit reasoning steps before the answer.
#   - **Role Prompting** → Assigns a persona to shape tone and style.
#   - **Deliberate Prompting** → Multiple reasoning paths → consistent final answer.
#   - **Prompt Chaining** → Sequential prompts → step-by-step workflow.
#   - **ReAct Prompting** → Combines reasoning + tool actions for dynamic problem solving.
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# ReAct Prompt Example: Reason + Act
react_prompt = """
You are an assistant that uses Reason + Act.
Question: Multiply 23 by 47.
First, reason step by step about how to solve it.
Then, act by giving the final answer.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": react_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# **Reason:**
#
# To multiply two numbers, we need to follow the steps of the multiplication algorithm.
#
# First, we multiply each digit of the second number (47) by the first number (23). Here's how we do it:
#
# 1. Multiply 23 by 40 (the tens digit of 47):
#   - 23 × 40 = 920 (since 40 is 4 tens, it is the same as 23 × 4 × 10)
#   - Keep track of the tens place
#
# 2. Multiply 23 by 7 (the ones digit of 47):
#   - 23 × 7 = 161
#
# Now we need to add the numbers we got in steps 1 and 2, while considering their places:
# - We add 920 (from the tens place) and 0 (because 161 is less than 23 × 10, thus not carrying) to it, which will result in 920.
#
# - Now add 100 (the tens digit of 23 × 40 shifted by one place) and 61 (the ones digit of the 161 multiplied by 7)
# This yields 1000 + 980 + 161 which is the same as (980 + 161) + (1000).
# So  the result is 1141  or 1381.
#
# ...

# %% [markdown]
# ##  ReAct Prompting — What Happens Here
#
# ---
#
# ###  What Happens Here
# - **Reasoning Phase** → The model explains the steps (e.g., break 47 into 40 + 7, compute separately).
# - **Action Phase** → The model provides the final answer (1081).
# - This demonstrates how **ReAct combines thinking + doing** in one prompt.
#
# ---
#
# ###  Why ReAct Prompting is Useful
# - **Dynamic workflows** → Useful when tasks require both reasoning and tool actions.
# - **Transparency** → Shows the thought process before the final answer.
# - **Agentic AI foundation** → Enables models to act like agents that reason and interact with tools.
#
# ---
#
# ###  Insight
# ReAct Prompting is especially powerful for **agentic AI systems** where the model needs to both **reason logically** and **perform actions** (like searching, calculating, or retrieving data).
# It bridges the gap between **thought** and **execution**, making AI more interactive and reliable in real-world workflows.

# %% [markdown]
# ## 9. Contextual Prompting in Generative AI
#
# ---
#
# ####  Definition
# Contextual Prompting is a technique where you **provide background information, context, or supporting details** before asking the model to perform a task.
# - Instead of a bare question, you **frame the query with relevant context**.
# - This helps the model generate responses that are more accurate, relevant, and aligned with the situation.
#
# ---
#
# ####  How It Works
# 1. **Provide Background** → Add details about the scenario, domain, or constraints.
# 2. **Ask the Question** → Follow up with the actual task or query.
# 3. **Model Response** → The model uses the provided context to tailor its answer.
#
# ---
#
# ####  Why It Matters
# - **Improves Relevance** → The model adapts its answer to the given situation.
# - **Domain Adaptation** → Useful when working in specialized fields (medicine, law, education).
# - **Personalization** → Makes responses more tailored to the user’s needs.
# - **Reduces Ambiguity** → Context clarifies vague or open-ended questions.
#
# ---
#
# ####  Use Cases
# - **Education** → "You are teaching 10-year-olds about fractions. Explain in simple terms."
# - **Business** → "We are preparing a pitch for a healthcare startup. Suggest 3 key talking points."
# - **Programming** → "In the context of Python data science, explain how NumPy arrays differ from lists."
# - **Creative Writing** → "Imagine a futuristic city in 2100. Write a short description of daily life."
#
# ---
#
# ####  Example (Conceptual)
# **Prompt:**
# "Context: You are helping a beginner learn Python.
# Task: Explain how loops work with a simple example."
#
# **Model Response (Contextual):**
# "Since the learner is a beginner, I’ll explain loops in simple terms.
# A loop lets you repeat actions. For example:
# ```python
# for i in range(5):
#     print(i)

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Contextual Prompt Example: Teaching Loops to a Beginner
contextual_prompt = """
Context: You are helping a beginner learn Python.
Task: Explain how loops work with a simple example.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": contextual_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Loops are a fundamental concept in programming that allow you to repeat a block of code multiple times. In this example, we'll use a simple print loop to demonstrate how loops work.
#
# ### Basic Syntax
#
# In Python, there are two main types of loops:
#
# 1. **For Loop**: This loop is used when you know the number of iterations in advance.
# 2. **While Loop**: This loop is used when you don't know the number of iterations in advance.
#
# ### For Loop
#
# A for loop is used to iterate over a sequence (like a list, tuple, dictionary, etc.) or other iterable objects.
#
# ```python
# # Example: Print the numbers from 1 to 5
# fruits = ['apple', 'banana', 'cherry']
# for fruit in fruits:
#     print(fruit)
# ```
#
# In this example, we have a list of fruits. The `for` loop iterates over each item in the list and prints it.
#
# Here's how it works:
#
# 1. The loop starts at the beginning of the list.
# 2. It assigns the first item (`'apple'`) to the variable `fruit`.
# ...

# %% [markdown]
# #### Contextual Prompting — What Happens Here
#
# ---
# - **Context Provided** → The model is told the learner is a beginner.
# - **Task Asked** → Explain loops in Python.
# - **Response Style** → The model adapts its explanation to be simple, beginner‑friendly, and uses easy examples.
#
# ---
#
# ####  Why Contextual Prompting is Useful
# - Ensures the answer is **tailored to the situation** (beginner vs expert).
# - Reduces ambiguity by **framing the query with background info**.
# - Makes responses **more relevant, accurate, and personalized**.
#
# ---
#
# #### Insight
# Contextual Prompting is especially powerful when you want the model to **adapt its response to a specific audience, domain, or scenario**.
# By embedding background information, you guide the model to produce **clearer, more context‑aware outputs**.

# %% [markdown]
# ## 10. Conversational Prompting in Generative AI
#
# ---
#
# ####  Definition
# Conversational Prompting is a technique where the model is guided to **simulate dialogue with alternating turns**.
# - Instead of a single command, the prompt is structured as a back‑and‑forth conversation.
# - This helps the model generate responses that feel natural, interactive, and context‑aware.
#
# ---
#
# ####  How It Works
# 1. **Set the Dialogue Context** → Provide a scenario or role (e.g., teacher and student).
# 2. **Alternate Turns** → Write prompts as if two people are talking.
# 3. **Model Response** → The model continues the dialogue in a conversational style.
#
# ---
#
# ####  Why It Matters
# - **Natural Flow** → Produces outputs that mimic human conversation.
# - **Engagement** → Useful for training, simulations, or role‑play scenarios.
# - **Context Retention** → The model remembers previous turns and builds on them.
# - **Interactive Learning** → Great for teaching or coaching environments.
#
# ---
#
# ####  Use Cases
# - **Education** → Simulate teacher‑student Q&A sessions.
# - **Customer Support** → Practice support agent and customer dialogues.
# - **Interview Prep** → Mock interviews with alternating questions and answers.
# - **Storytelling** → Characters talking to each other in a narrative.
#
# ---
#
# ####  Example (Conceptual)
# **Prompt:**
# "Simulate a conversation between a teacher and a student learning Python.
# Teacher: What is a loop?
# Student: I’m not sure. Could you explain?
# Teacher: …"
#
# **Model Response (Conversational):**
# "Teacher: A loop is a way to repeat actions. For example, in Python:
# ```python
# for i in range(5):
#     print(i)

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Conversational Prompt Example: Teacher-Student Dialogue
conversational_prompt = """
Simulate a conversation between a teacher and a student learning Python.

Teacher: What is a loop?
Student: I’m not sure. Could you explain?
Teacher:
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": conversational_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Teacher: A loop is a control structure in Python (and programming languages in general) that allows you to repeat a block of code multiple times. Think of it like a conveyor belt - you can place items on the belt and it will keep moving until it reaches the end.
#
# Imagine you're making copies of a document. Instead of copying it manually each time, you can use a loop to tell the copier to make copies until you're out of paper. This saves you a lot of time and effort.
#
# In Python, there are two main types of loops: for loops and while loops. A for loop is used when you know how many times you want to repeat the code, but a while loop is used when you're not sure how many times you want to repeat the code, and it depends on a certain condition being met.
#
# Would you like to see an example of a for loop in action?

# %% [markdown]
# #### Conversational Prompting — What Happens Here
#
# ---
#
# #### What Happens Here
# - **Prompt Structure** → Written as a dialogue with alternating turns.
# - **Model Response** → Continues the conversation naturally, explaining loops in a teacher‑student style.
# - **Outcome** → Produces interactive, context‑aware dialogue that feels human‑like.
#
# ---
#
# #### Why Conversational Prompting is Useful
# - Creates natural, flowing dialogue for simulations or role‑play.
# - Helps in education, customer support, and interview practice.
# - Ensures the model retains context across turns and builds on prior exchanges.
#
# ---
#
# #### Insight
# Conversational Prompting is especially powerful when you want the model to **simulate dialogue**.
# By structuring prompts as alternating turns, you guide the model to produce **interactive, context‑aware outputs** that feel more human and engaging.

# %% [markdown]
# #### 11. Multimodal Prompting in Generative AI
#
# ---
#
# ####  Definition
# Multimodal Prompting is a technique where the model is guided using **multiple types of input** such as text, images, audio, or video.
# - Instead of relying only on text, you combine different modalities to enrich the prompt.
# - This allows the model to generate responses that integrate information across formats.
#
# ---
#
# #### How It Works
# 1. **Provide Multiple Inputs** → Text plus another modality (image, audio, video).
# 2. **Frame the Task** → Ask the model to analyze or combine these inputs.
# 3. **Model Response** → The model produces an output that integrates the modalities.
#
# ---
#
# #### Why It Matters
# - **Richer Understanding** → Models can interpret visual, auditory, and textual cues together.
# - **Enhanced Creativity** → Useful for storytelling, design, and multimedia projects.
# - **Practical Applications** → Enables tasks like captioning, visual Q&A, and multimodal search.
# - **Human‑like Interaction** → Mirrors how people process information from multiple senses.
#
# ---
#
# #### Use Cases
# - **Education** → Provide a diagram plus text, ask the model to explain.
# - **Healthcare** → Combine patient notes with medical images for analysis.
# - **Business** → Use charts plus text to generate insights.
# - **Creative Writing** → Provide an image and ask for a descriptive story.
#
# ---
#
# #### Example (Conceptual)
# **Prompt:**
# "Here is an image of a bar chart showing sales growth from 2020 to 2025.
# Task: Write a short summary explaining the trend."
#
# **Model Response (Multimodal):**
# "The chart shows steady growth in sales from 2020 to 2025, with the largest increase between 2023 and 2024. This suggests strong market expansion during that period."
#
# ---
#
# #### Key Insights
# - Multimodal Prompting is about **combining text with other inputs**.
# - Compared to other techniques:
#   - **Instruction Prompt** → Direct command.
#   - **Zero‑Shot Prompt** → No examples, relies on pretrained knowledge.
#   - **Few‑Shot Prompt** → A few examples guide the output.
#   - **Chain‑of‑Thought Prompt** → Explicit reasoning steps before the answer.
#   - **Role Prompting** → Assigns a persona to shape tone and style.
#   - **Deliberate Prompting** → Multiple reasoning paths → consistent final answer.
#   - **Prompt Chaining** → Sequential prompts → step‑by‑step workflow.
#   - **ReAct Prompting** → Combines reasoning + tool actions.
#   - **Contextual Prompting** → Provides background info → tailored response.
#   - **Conversational Prompting** → Simulates dialogue with alternating turns.
#   - **Multimodal Prompting** → Combines text + image/audio/video for richer interaction.
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# Multimodal Prompt Example: Text + Image Description
multimodal_prompt = """
You are given a description of an image:
'The image shows a bar chart of sales growth from 2020 to 2025, 
with steady increases each year and the largest jump between 2023 and 2024.'

Task: Write a short summary explaining the trend in sales growth.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": multimodal_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The sales growth trend from 2020 to 2025 exhibits a steady upward trajectory, with consistent increases each year. However, there is a notable surge in growth between 2023 and 2024, suggesting a significant acceleration in sales expansion during this period. Overall, the chart indicates a sustained and rapid growth in sales over the five-year period.

# %% [markdown]
# #### Multimodal Prompting — What Happens Here
#
# ---
#
# #### What Happens Here
# - **Prompt Structure** → Text plus a description of an image (simulated multimodal input).
# - **Model Response** → Summarizes the trend by integrating the described visual data.
# - **Outcome** → Shows how multimodal prompting can combine text with other modalities for richer insights.
#
# ---
#
# #### Why Multimodal Prompting is Useful
# - Enables the model to interpret and integrate multiple input types.
# - Useful for education, business analytics, healthcare, and creative storytelling.
# - Mirrors how humans process information from different senses together.
#
# ---
#
# #### Insight
# Multimodal Prompting is especially powerful when you want the model to **combine text with other modalities**.
# By embedding descriptions of images, audio, or video alongside text, you guide the model to produce **richer, context‑aware outputs** that go beyond text‑only reasoning.

# %% [markdown]
# ## 12. Retrieval‑Augmented Generation (RAG Prompting)
#
# ---
#
# ####  Definition
# RAG Prompting is a technique where the **Large Language Model (LLM)** is combined with an **external knowledge source** (such as a database, document store, or search engine).
# - The model retrieves relevant information first.
# - Then it generates a response using both the retrieved data and its own reasoning.
# - This ensures answers are **accurate, up‑to‑date, and grounded in external facts**.
#
# ---
#
# ####  How It Works
# 1. **User Query** → The user asks a question.
# 2. **Retrieval Step** → The system searches external sources (documents, APIs, web).
# 3. **Augmentation Step** → Retrieved information is fed into the prompt.
# 4. **Generation Step** → The LLM produces a final answer using both context + knowledge.
#
# ---
#
# ####  Why It Matters
# - **Accuracy** → Reduces hallucinations by grounding answers in real data.
# - **Freshness** → Provides up‑to‑date information beyond the model’s training cutoff.
# - **Domain Adaptation** → Useful for specialized fields (medicine, law, finance).
# - **Trustworthiness** → Responses can be traced back to sources.
#
# ---
#
# ####  Use Cases
# - **Customer Support** → Retrieve FAQs or manuals, then generate tailored answers.
# - **Education** → Pull from textbooks or lecture notes to answer student queries.
# - **Business Intelligence** → Retrieve company data, then generate insights.
# - **Healthcare** → Retrieve medical guidelines, then explain treatment options.
#
# ---
#
# ####  Example (Conceptual)
# **Prompt:**
# "Using the latest WHO data, summarize the global COVID‑19 vaccination rate."
#
# **Model Response (RAG style):**
# - **Retrieval:** WHO database shows vaccination coverage at ~70% globally (2025).
# - **Generation:** "As of 2025, about 70% of the global population has received at least one dose of a COVID‑19 vaccine, with higher coverage in developed regions compared to developing ones."
#
# ---

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# RAG Prompt Example: Retrieval + Generation
rag_prompt = """
You are an assistant that uses Retrieval-Augmented Generation (RAG).
Here is retrieved information from WHO (simulated):
'As of 2025, about 70% of the global population has received at least one dose of a COVID-19 vaccine.'

Task: Using this retrieved data, generate a short summary of the global COVID-19 vaccination rate.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",   # valid Groq model
    messages=[
        {"role": "user", "content": rag_prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Based on the retrieved information from WHO, I can generate a short summary:
#
# "As of 2025, significant progress has been made in global COVID-19 vaccination efforts. Approximately 70% of the world's population has received at least one dose of a COVID-19 vaccine, indicating a substantial decline in reported cases and a reduced threat of severe illness."

# %% [markdown]
# #### Retrieval‑Augmented Generation (RAG Prompting) — What Happens Here
#
# ---
#
# #### What Happens Here
# - **Prompt Structure** → Includes both the user query and retrieved external knowledge (e.g., WHO data snippet).
# - **Model Response** → Uses the retrieved information to generate a grounded, accurate answer.
# - **Outcome** → Produces reliable, up‑to‑date responses that can be traced back to external sources.
#
# ---
#
# #### Why RAG Prompting is Useful
# - Reduces hallucinations by grounding answers in **real data**.
# - Provides **fresh, domain‑specific knowledge** beyond the model’s training cutoff.
# - Ensures **trustworthiness** by linking responses to external sources.
# - Enables **specialized applications** in education, healthcare, business, and customer support.
#
# ---
#
# #### Insight
# RAG Prompting is especially powerful when you need the model to **combine its reasoning with external knowledge**.
# By retrieving relevant information first and then generating an answer, you guide the model to produce **accurate, context‑aware outputs** that are both reliable and explainable.

# %% [markdown]
# #### Prompt Engineering Techniques — Complete Cheat‑Sheet (1–12)
#
# ---
#
# #### 1. Instruction Prompting
# **Definition:** Directly tell the model what to do.
# **Example:** "Summarize this article in 3 bullet points."
# **Insight:** Best for straightforward tasks where clarity is key.
#
# ---
#
# #### 2. Zero‑Shot Prompting
# **Definition:** Ask the model to perform a task without giving examples.
# **Example:** "Translate 'Hello, how are you?' into French."
# **Insight:** Relies entirely on the model’s pretraining knowledge.
#
# ---
#
# #### 3. Few‑Shot Prompting
# **Definition:** Provide a few examples before asking the model to perform a similar task.
# **Example:**
# "Translate the following sentences into French:
# - I am happy → Je suis heureux
# - She is a teacher → Elle est professeur
# Now translate: He is a doctor."
# **Insight:** Helps guide the model toward the desired format or style.
#
# ---
#
# #### 4. Chain‑of‑Thought Prompting
# **Definition:** Encourage the model to reason step by step before giving the final answer.
# **Example:** "Explain your reasoning step by step before solving 23 × 47."
# **Insight:** Improves accuracy in math, logic, and complex reasoning tasks.
#
# ---
#
# #### 5. Role‑Based Prompting
# **Definition:** Assign the model a persona or role to shape its response style.
# **Example:** "You are a Python tutor. Explain loops to a beginner."
# **Insight:** Useful for tailoring tone, depth, and perspective.
#
# ---
#
# #### 6. Deliberate (Self‑Consistency) Prompting
# **Definition:** Ask the model to generate multiple reasoning paths and then choose the most consistent answer.
# **Example:** "Solve this math problem three different ways, then give the final consistent answer."
# **Insight:** Reduces errors by cross‑checking reasoning.
#
# ---
#
# #### 7. Prompt Chaining
# **Definition:** Break a task into multiple sequential prompts, each building on the previous.
# **Example:**
# Step 1: "Summarize this article."
# Step 2: "From the summary, extract 3 key insights."
# Step 3: "Turn those insights into a LinkedIn post."
# **Insight:** Useful for complex workflows and multi‑stage tasks.
#
# ---
#
# #### 8. ReAct Prompting (Reason + Act)
# **Definition:** Combine reasoning with actions (e.g., tool use, search, calculation).
# **Example:**
# - Reason: "To answer, I need Japan’s current population."
# - Act: "Search for Japan’s population."
# - Observation: "Population ~124 million."
# - Final Answer: "Japan’s population has declined since 2020."
# **Insight:** Foundation for agentic AI systems that both think and act.
#
# ---
#
# #### 9. Contextual Prompting
# **Definition:** Provide background information before asking the question.
# **Example:**
# "Context: You are helping a beginner learn Python.
# Task: Explain how loops work with a simple example."
# **Insight:** Makes responses more tailored, relevant, and audience‑specific.
#
# ---
#
# #### 10. Conversational Prompting
# **Definition:** Structure prompts as dialogue with alternating turns.
# **Example:**
# Teacher: "What is a loop?"
# Student: "I’m not sure. Could you explain?"
# Teacher: …
# **Insight:** Produces natural, interactive, context‑aware dialogue.
#
# ---
#
# #### 11. Multimodal Prompting
# **Definition:** Combine text with other modalities (image, audio, video).
# **Example:**
# "Here is an image of a bar chart showing sales growth.
# Task: Write a short summary explaining the trend."
# **Insight:** Enables richer, human‑like interaction by integrating multiple input types.
#
# ---
#
# #### 12. Retrieval‑Augmented Generation (RAG Prompting)
# **Definition:** Retrieve external knowledge first, then generate an answer using it.
# **Example:**
# Retrieved Data: "WHO reports 70% global vaccination coverage in 2025."
# Prompt: "Summarize the global COVID‑19 vaccination rate using this data."
# **Insight:** Ensures answers are accurate, up‑to‑date, and grounded in real sources.
#
# ---
#
# #### Final Insight
# Together, these **12 techniques** form a complete toolkit for prompt engineering:
# - **Basic Control:** Instruction, Zero‑Shot, Few‑Shot
# - **Reasoning:** Chain‑of‑Thought, Deliberate, Prompt Chaining
# - **Agentic & Contextual:** ReAct, Contextual, Conversational
# - **Advanced:** Multimodal, RAG

# %% [markdown]
# <hr style="border:2px solid #4CAF50">
#
# #### 1. Instruction Prompting
# **Definition:** Directly tell the model what to do.
# **Example:** "Summarize this article in 3 bullet points."
# **Insight:** Best for straightforward tasks where clarity is key.
#
# <hr style="border:2px solid #2196F3">
#
# #### 2. Zero‑Shot Prompting
# **Definition:** Ask the model to perform a task without giving examples.
# **Example:** "Translate 'Hello, how are you?' into French."
# **Insight:** Relies entirely on the model’s pretraining knowledge.
#
# <hr style="border:2px solid #FF9800">
#
# #### 3. Few‑Shot Prompting
# **Definition:** Provide a few examples before asking the model to perform a similar task.
# **Example:**
# "Translate the following sentences into French:
# - I am happy → Je suis heureux
# - She is a teacher → Elle est professeur
# Now translate: He is a doctor."
# **Insight:** Helps guide the model toward the desired format or style.
#
# <hr style="border:2px solid #9C27B0">
#
# #### 4. Chain‑of‑Thought Prompting
# **Definition:** Encourage the model to reason step by step before giving the final answer.
# **Example:** "Explain your reasoning step by step before solving 23 × 47."
# **Insight:** Improves accuracy in math, logic, and complex reasoning tasks.
#
# <hr style="border:2px solid #795548">
#
# #### 5. Role‑Based Prompting
# **Definition:** Assign the model a persona or role to shape its response style.
# **Example:** "You are a Python tutor. Explain loops to a beginner."
# **Insight:** Useful for tailoring tone, depth, and perspective.
#
# <hr style="border:2px solid #E91E63">
#
# #### 6. Deliberate (Self‑Consistency) Prompting
# **Definition:** Ask the model to generate multiple reasoning paths and then choose the most consistent answer.
# **Example:** "Solve this math problem three different ways, then give the final consistent answer."
# **Insight:** Reduces errors by cross‑checking reasoning.
#
# <hr style="border:2px solid #607D8B">
#
# #### 7. Prompt Chaining
# **Definition:** Break a task into multiple sequential prompts, each building on the previous.
# **Example:**
# Step 1: "Summarize this article."
# Step 2: "From the summary, extract 3 key insights."
# Step 3: "Turn those insights into a LinkedIn post."
# **Insight:** Useful for complex workflows and multi‑stage tasks.
#
# <hr style="border:2px solid #4CAF50">
#
# #### 8. ReAct Prompting (Reason + Act)
# **Definition:** Combine reasoning with actions (e.g., tool use, search, calculation).
# **Example:**
# - Reason: "To answer, I need Japan’s current population."
# - Act: "Search for Japan’s population."
# - Observation: "Population ~124 million."
# - Final Answer: "Japan’s population has declined since 2020."
# **Insight:** Foundation for agentic AI systems that both think and act.
#
# <hr style="border:2px solid #2196F3">
#
# #### 9. Contextual Prompting
# **Definition:** Provide background information before asking the question.
# **Example:**
# "Context: You are helping a beginner learn Python.
# Task: Explain how loops work with a simple example."
# **Insight:** Makes responses more tailored, relevant, and audience‑specific.
#
# <hr style="border:2px solid #FF9800">
#
# #### 10. Conversational Prompting
# **Definition:** Structure prompts as dialogue with alternating turns.
# **Example:**
# Teacher: "What is a loop?"
# Student: "I’m not sure. Could you explain?"
# Teacher: …
# **Insight:** Produces natural, interactive, context‑aware dialogue.
#
# <hr style="border:2px solid #9C27B0">
#
# #### 11. Multimodal Prompting
# **Definition:** Combine text with other modalities (image, audio, video).
# **Example:**
# "Here is an image of a bar chart showing sales growth.
# Task: Write a short summary explaining the trend."
# **Insight:** Enables richer, human‑like interaction by integrating multiple input types.
#
# <hr style="border:2px solid #795548">
#
# #### 12. Retrieval‑Augmented Generation (RAG Prompting)
# **Definition:** Retrieve external knowledge first, then generate an answer using it.
# **Example:**
# Retrieved Data: "WHO reports 70% global vaccination coverage in 2025."
# Prompt: "Summarize the global COVID‑19 vaccination rate using this data."
# **Insight:** Ensures answers are accurate, up‑to‑date, and grounded in real sources.
#
# <hr style="border:2px solid #000000">
#
# #### Final Insight
# Together, these **12 techniques** form a complete toolkit for prompt engineering:
# - **Basic Control:** Instruction, Zero‑Shot, Few‑Shot
# - **Reasoning:** Chain‑of‑Thought, Deliberate, Prompt Chaining
# - **Agentic & Contextual:** ReAct, Contextual, Conversational
# - **Advanced:** Multimodal, RAG

# %% [markdown]
# #### Prompt Engineering Techniques — Comparison Table
#
# | Technique | Definition | Example | Best Use Case |
# |-----------|------------|---------|---------------|
# | **Instruction Prompting** | Directly tell the model what to do. | "Summarize this article in 3 bullet points." | Simple, clear tasks where precision is needed. |
# | **Zero‑Shot Prompting** | Ask the model to perform a task without examples. | "Translate 'Hello, how are you?' into French." | Quick tasks relying on pretrained knowledge. |
# | **Few‑Shot Prompting** | Provide a few examples before the query. | "Translate: I am happy → Je suis heureux; She is a teacher → Elle est professeur. Now translate: He is a doctor." | When you want the model to mimic a specific format or style. |
# | **Chain‑of‑Thought Prompting** | Encourage step‑by‑step reasoning before the answer. | "Explain your reasoning step by step before solving 23 × 47." | Math, logic, or complex reasoning problems. |
# | **Role‑Based Prompting** | Assign a persona or role to shape responses. | "You are a Python tutor. Explain loops to a beginner." | Teaching, coaching, or tone‑specific tasks. |
# | **Deliberate (Self‑Consistency) Prompting** | Generate multiple reasoning paths, then choose the consistent answer. | "Solve this math problem three different ways, then give the final consistent answer." | Reducing errors in reasoning‑heavy tasks. |
# | **Prompt Chaining** | Break tasks into sequential prompts. | Step 1: Summarize article → Step 2: Extract insights → Step 3: Write LinkedIn post. | Multi‑stage workflows, content pipelines. |
# | **ReAct Prompting (Reason + Act)** | Combine reasoning with tool actions. | Reason: Need Japan’s population → Act: Search → Observation: 124M → Final Answer: Declined since 2020. | Agentic AI, tasks needing external tools or APIs. |
# | **Contextual Prompting** | Provide background info before asking. | "Context: You are helping a beginner learn Python. Task: Explain loops simply." | Tailored, audience‑specific responses. |
# | **Conversational Prompting** | Structure prompts as dialogue with alternating turns. | Teacher: "What is a loop?" Student: "I’m not sure." Teacher: … | Simulations, role‑play, interactive learning. |
# | **Multimodal Prompting** | Combine text with other inputs (image, audio, video). | "Here is an image of a bar chart. Task: Summarize the trend." | Education, analytics, creative storytelling. |
# | **RAG Prompting** | Retrieve external knowledge, then generate an answer. | Retrieved Data: WHO reports 70% vaccination. Prompt: "Summarize global vaccination rate." | Accurate, up‑to‑date answers in specialized domains. |
#
# ---
#
# #### Insight
# - **Basic Control:** Instruction, Zero‑Shot, Few‑Shot → Best for simple tasks.
# - **Reasoning:** Chain‑of‑Thought, Deliberate, Prompt Chaining → Best for logic and multi‑step workflows.
# - **Agentic & Contextual:** ReAct, Contextual, Conversational → Best for interactive, tool‑driven, or audience‑specific tasks.
# - **Advanced:** Multimodal, RAG → Best for real‑world applications needing external data or multiple input types.
